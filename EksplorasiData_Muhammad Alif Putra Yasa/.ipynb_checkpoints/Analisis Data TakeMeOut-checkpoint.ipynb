# %% [markdown]
# # Analisis Data TakeMeOut

# %% [markdown]
# <pre>
# Nama        : Muhammad Alif Putra Yasa
# NIM         : 16520301
# Universitas : Institut Teknologi Bandung
# Data        : TakeMeOut
# Pengerjaan  : 6 November 2020
# </pre>

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# Langkah pertama yang dilakukan adalah meng-*import* *library* dan membaca data dari file .csv

# %%
# Import Library
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as spsts
import collections as col

# Membaca Data
data = pd.read_csv('takemeout.csv')

# %%
# Melihat data
data.head()
# Out:
#                      Timestamp Siapa nama kamu? Cewek atau cowok nih?  \
# 0  2020/10/31 3:39:25 PM GMT+7  A**************                 Cowok
# 1  2020/10/31 3:39:36 PM GMT+7            L****                 Cewek
# 2  2020/10/31 3:39:38 PM GMT+7     Y***********                 Cowok
# 3  2020/10/31 3:39:42 PM GMT+7             a***                 Cowok
# 4  2020/10/31 3:39:43 PM GMT+7            B****                 Cowok
#
#    Seberapa penting quality time bareng calon pacar untuk kamu?  \
# 0                                                  5
# 1                                                  5
# 2                                                  4
# 3                                                  5
# 4                                                  5
#
#    Seberapa penting physical touch sama calon pacar untuk kamu?  \
# 0                                                  5
# 1                                                  5
# 2                                                  3
# 3                                                  5
# 4                                                  5
#
#    Seberapa penting word of affirmation dari calon pacar untuk kamu?  \
# 0                                                  4
# 1                                                  3
# 2                                                  4
# 3                                                  5
# 4                                                  5
#
#    Seberapa penting dapet kado dari calon pacar untuk kamu?  \
# 0                                                  1
# 1                                                  2
# 2                                                  4
# 3                                                  2
# 4                                                  2
#
#    Seberapa penting bantuan dari calon pacar untuk kamu?
# 0                                                  3
# 1                                                  2
# 2                                                  4
# 3                                                  3
# 4                                                  4

# %% [markdown]
# Data yang tidak digunakan di analisis, seperti *Timestamp* dan Nama (Semua nama disensor, sehingga tidak berguna), dihapus atau disingkat.

# %%
# Membenahi nama kolom
del data['Timestamp']
column_names = ['Nama', 'Gender', 'Quality Time', 'Physical Touch', 'Affirmation', 'Kado', 'Bantuan']
data.columns = column_names

# Menyingkat Nama
for i in data['Nama']:
    if len(i) > 2:
        data['Nama'] = data['Nama'].replace( i, i[:1] + str(len(i) - 2) + '*')
        
# Memisahkan data cowok dan cewek
cowok_data = data.loc[data['Gender'] == 'Cowok']
cewek_data = data.loc[data['Gender'] == 'Cewek']

# %%
data.head()
# Out:
#    Nama Gender  Quality Time  Physical Touch  Affirmation  Kado  Bantuan
# 0  A13*  Cowok             5               5            4     1        3
# 1   L3*  Cewek             5               5            3     2        2
# 2  Y10*  Cowok             4               3            4     4        4
# 3   a1*  Cowok             5               5            5     2        3
# 4   B3*  Cowok             5               5            5     2        4

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# Data yang diperoleh berbentuk *ordinal data*

# %% [markdown]
# ### Statistik Dasar

# %%
# Statistik dasar data keseluruhan
sts_dasar = {
    "Max"    : [ np.max(data[kolom]) for kolom in column_names[2:] ],
    "Min"    : [ np.min(data[kolom]) for kolom in column_names[2:] ],
    "Mode"   : [ int(spsts.mode(data[kolom])[0]) for kolom in column_names[2:] ],
    "Median" : [ int(np.median(data[kolom])) for kolom in column_names[2:] ]
}

tabel_sts       = pd.DataFrame(sts_dasar)
tabel_sts.style.set_caption("Hello World")
tabel_sts.index = column_names[2:]
tabel_sts
# Out:
#                 Max  Min  Mode  Median
# Quality Time      5    1     5       5
# Physical Touch    5    1     3       3
# Affirmation       5    1     4       4
# Kado              5    1     3       3
# Bantuan           5    1     4       4

# %%
# Statistik dasar data cowok
cowok_sts = {
    "Max"    : [ np.max(cowok_data[kolom]) for kolom in column_names[2:] ],
    "Min"    : [ np.min(cowok_data[kolom]) for kolom in column_names[2:] ],
    "Mode"   : [ int(spsts.mode(cowok_data[kolom])[0]) for kolom in column_names[2:] ],
    "Median" : [ int(np.median(data[kolom])) for kolom in column_names[2:] ]
}

tabel_sts_cowok = pd.DataFrame(cowok_sts)
tabel_sts_cowok.index = column_names[2:]
tabel_sts_cowok
# Out:
#                 Max  Min  Mode  Median
# Quality Time      5    1     5       5
# Physical Touch    5    1     3       3
# Affirmation       5    1     4       4
# Kado              5    1     3       3
# Bantuan           5    1     4       4

# %%
# Statistik dasar data cewek
cewek_sts = {
    "Max"    : [ np.max(cewek_data[kolom]) for kolom in column_names[2:] ],
    "Min"    : [ np.min(cewek_data[kolom]) for kolom in column_names[2:] ],
    "Mode"   : [ int(spsts.mode(cewek_data[kolom])[0]) for kolom in column_names[2:] ],
    "Median" : [ int(np.median(data[kolom])) for kolom in column_names[2:] ]
}

tabel_sts_cewek = pd.DataFrame(cewek_sts)
tabel_sts_cewek.index = column_names[2:]
tabel_sts_cewek
# Out:
#                 Max  Min  Mode  Median
# Quality Time      5    1     4       5
# Physical Touch    5    1     1       3
# Affirmation       5    1     3       4
# Kado              5    1     1       3
# Bantuan           5    1     5       4

# %% [markdown]
# ## Visualisasi Data

# %%
# Mengatur ukuran
plt.rcParams['figure.figsize'] = [2 *10 *1.6 /2.54, 6 *10 /2.54]

#   Untuk membuat judul umum bar chart dan pie chart, 
# langkah awal yang dilakukan adalah membuat 5 Grafik

fig, main_axes = plt.subplots(nrows=5, ncols=1, sharey=True)
plt.subplots_adjust(hspace=0.3)

for row, main_ax in enumerate(main_axes, start=1):
    # Memberi nama grafik
    main_ax.set_title(column_names[2:][row-1], fontsize=15)
    # Membuat grafik tidak terlihat
    main_ax.axis('off')

#   Setelah membuat 5 grafik yang tidak terlihat tetapi judulnya
# tetap terlihat, langkah selanjutnya adalah mengisinya dengan
# bar chart dan pie chart
    
# Membuat 10 plot
for i in range(10):
    # Membuat subplot dengan 5 row dan
    # 2 kolom. i + 1 adalah index plot
    sub_ax = fig.add_subplot(5,2,i+1)
    
    # Data dihitung dan diurut
    hitungData = col.Counter(data[column_names[2:][i//2]])
    urutHitData = sorted(hitungData.items())
    
    # Untuk plot di kiri, bar chart
    if i % 2 == 0:
        sub_ax.bar([i[0] for i in urutHitData],
                [i[1] for i in urutHitData],
                color = 'skyblue')
        plt.setp(sub_ax,
                 xlabel='Tingkat Kesukaan',
                 ylabel = 'Frekuensi')
    
    # Untuk plot di kanan, pie chart
    else:
        sub_ax.pie([i[1] for i in urutHitData],
               labels=[i[0] for i in urutHitData],
               autopct='%1.1f%%')

# Supaya ukurannya pas dengan aturan ukuran
plt.tight_layout()

plt.show()

# %% [markdown]
# ## Insights

# %% [markdown]
# Dengan menggunakan [Spearman rank correlation](https://en.wikipedia.org/wiki/Spearman%27s_rank_correlation_coefficient), kita dapatkan bahwa:

# %%
# Pasangan Korelasi
aspect = []

# Koefisien Korelasi
coeff = []

# Interpretasi
interp = []

for i in range(4):
    for k in range(i+1, 5):
        aspect += [column_names[2:][i] + ' & ' + column_names[2:][k]]
        res = spsts.spearmanr(data[column_names[2:][i]], data[column_names[2:][k]])[0]
        
        # Koefisiennya 3 angka belakang koma aja
        coeff += [round(res,3)]
        
        # Hasil yang memungkinkan
        if res > 0.9:
            verdict = 'Very high'
        elif res > 0.7 and res <= 0.9:
            verdict = 'High'
        elif res > 0.5 and res <= 0.7:
            verdict = 'Moderate'
        elif res > 0.3 and res <= 0.5:
            verdict = 'Low'
        else:
            verdict = 'Little to none'
        interp += [verdict + ' correlation']

insights = {
    'Correlation coefficient' : coeff,
    'Interpretation' : interp
}

# Bikin Dataframe
result = pd.DataFrame(insights,
                      index = aspect)
# Menunjukkan Hasil
result
# Out:
#                                Correlation coefficient  \
# Quality Time & Physical Touch                    0.466
# Quality Time & Affirmation                       0.531
# Quality Time & Kado                              0.376
# Quality Time & Bantuan                           0.205
# Physical Touch & Affirmation                     0.554
# Physical Touch & Kado                            0.428
# Physical Touch & Bantuan                         0.124
# Affirmation & Kado                               0.442
# Affirmation & Bantuan                            0.371
# Kado & Bantuan                                   0.389
#
#                                            Interpretation
# Quality Time & Physical Touch             Low correlation
# Quality Time & Affirmation           Moderate correlation
# Quality Time & Kado                       Low correlation
# Quality Time & Bantuan         Little to none correlation
# Physical Touch & Affirmation         Moderate correlation
# Physical Touch & Kado                     Low correlation
# Physical Touch & Bantuan       Little to none correlation
# Affirmation & Kado                        Low correlation
# Affirmation & Bantuan                     Low correlation
# Kado & Bantuan                            Low correlation

# %% [markdown]
# Kesimpulan
#  - Quality Time dan Word of Affirmation berkorelasi sedang
#  - Physical Touch and Word of Affirmation berkorelasi sedang
#  - Quality Time dan Word of Affirmation itu penting
