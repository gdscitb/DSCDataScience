# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r"C:\Users\rofif\OneDrive\Dokumen\DSCITB\DataScience\DSCDataScience\EksplorasiData_Rofif\IDN-covid.csv")

# %%
data.head()
# Out:
#        Date  Cumulative_cases  Recovered_cases  Total_death  \
# 0  3/2/2020                 2                0            0
# 1  3/3/2020                 2                0            0
# 2  3/4/2020                 2                0            0
# 3  3/5/2020                 2                0            0
# 4  3/6/2020                 4                0            0
#
#    Patient_under_treatment  New_case_perDay  Recovered-cases_perDay  \
# 0                        2                2                       0
# 1                        2                2                       0
# 2                        2                2                       0
# 3                        2                2                       0
# 4                        4                2                       0
#
#    Death_cases_perDay  Treatment_cases_perDay
# 0                   0                       2
# 1                   0                       2
# 2                   0                       2
# ...

# %%
#untuk mengecek nama nama variable kolom

# %%
data.columns
# Out:
# Index(['Date', 'Cumulative_cases', 'Recovered_cases', 'Total_death',
#        'Patient_under_treatment', 'New_case_perDay', 'Recovered-cases_perDay',
#        'Death_cases_perDay', 'Treatment_cases_perDay'],
#       dtype='object')

# %%
# untuk mencari nilai max min avg dll, disetiap kolom

# %%
data.describe()
# Out:
#        Cumulative_cases  Recovered_cases   Total_death  \
# count        255.000000       255.000000    255.000000
# mean      122948.788235     87855.325490   4891.752941
# std       134262.629875    110275.155188   4598.168085
# min            2.000000         0.000000      0.000000
# 25%        11829.000000      2075.500000    868.000000
# 50%        66226.000000     30785.000000   3309.000000
# 75%       201688.500000    144079.000000   8283.000000
# max       448118.000000    378982.000000  14836.000000
#
#        Patient_under_treatment  New_case_perDay  Recovered-cases_perDay  \
# count               255.000000       255.000000              255.000000
# mean              30201.686275      1757.384314             1486.278431
# std               21844.752721      1474.435689             1492.940758
# min                   2.000000         2.000000                0.000000
# 25%                8885.500000       397.500000              108.000000
# ...

# %%
# mengecek data tidak ada yang Null

# %%
data.isnull().sum()
# Out:
# Date                       0
# Cumulative_cases           0
# Recovered_cases            0
# Total_death                0
# Patient_under_treatment    0
# New_case_perDay            0
# Recovered-cases_perDay     0
# Death_cases_perDay         0
# Treatment_cases_perDay     0
# dtype: int64

# %% [markdown]
# # Merelasikan variabel dengan scatterplot

# %%
sns.pairplot(data)

# %%
sns.relplot(x="Cumulative_cases", y="Recovered_cases", data=data)

# %%
sns.relplot(x="Cumulative_cases", y="Patient_under_treatment", hue="Recovered-cases_perDay", data=data)

# %%
sns.relplot(x="Cumulative_cases", y="Patient_under_treatment", hue="Death_cases_perDay", data=data)

# %%
data.columns
# Out:
# Index(['Date', 'Cumulative_cases', 'Recovered_cases', 'Total_death',
#        'Patient_under_treatment', 'New_case_perDay', 'Recovered-cases_perDay',
#        'Death_cases_perDay', 'Treatment_cases_perDay'],
#       dtype='object')

# %%
sns.relplot(x="Cumulative_cases", y="Recovered_cases", kind="line", data=data)

# %%
sns.relplot(x="New_case_perDay", y="Death_cases_perDay", kind="line", data=data)
