# %% [markdown]
# # IDENTITAS

# %% [markdown]
# 1. Pembuat :
#             Nama : Novanni Indi Pradana
#             NIM  : 222011436
#             Asal : Politeknik Statistika STIS
#
# 2. Tanggal : 6 November 2020
# 3. Sumber  : Survey Gform "How To Make Sirkel Di STIS"

# %% [markdown]
# # DATA OBSERVATION

# %%
import pandas as pd

# %%
from sklearn.neighbors import NearestNeighbors

# %%
df = pd.read_csv('Assessment.csv')

# %%
df.head()
# Out:
#                       Timestamp Total score  \
# 0  2020/11/04 10:30:57 AM GMT+7    0.00 / 0
# 1  2020/11/04 10:31:13 AM GMT+7    0.00 / 0
# 2  2020/11/04 10:33:15 AM GMT+7    0.00 / 0
# 3  2020/11/04 10:33:59 AM GMT+7    0.00 / 0
# 4  2020/11/04 10:34:10 AM GMT+7    0.00 / 0
#
#                                 Nama Nama [Score]  Nama [Feedback]  Kelas  \
# 0                           Saffanah       -- / 0              NaN  D4-KS
# 1  Islamiati Yulia Mustikasari Lessy       -- / 0              NaN  D3-ST
# 2                         Muhammad H       -- / 0              NaN  D4-KS
# 3                      Wa ode raksni       -- / 0              NaN  D4-KS
# 4               Vannisya Tri Hapsari       -- / 0              NaN  D4-KS
#
#   Kelas [Score]  Kelas [Feedback]  Bagaimana Tipe Belajarmu?  \
# 0        -- / 0               NaN                          2
# 1        -- / 0               NaN                          2
# 2        -- / 0               NaN                          3
# ...

# %% [markdown]
# # DATA PREPARATION
#
# Pada tahap ini saya menata data dan membersihkan data yang akan saya gunakan dan tidak. Jika tidak diperlukan maka data tersebut akan saya hapus (kolom), sehingga proses akan lebih mudah. Data yang saya bersihkan adalah yang tidak memiliki nilai kuantitatif.

# %%
df = df.iloc[: , 1:]

# %%
df.head()
# Out:
#   Total score                               Nama Nama [Score]  \
# 0    0.00 / 0                           Saffanah       -- / 0
# 1    0.00 / 0  Islamiati Yulia Mustikasari Lessy       -- / 0
# 2    0.00 / 0                         Muhammad H       -- / 0
# 3    0.00 / 0                      Wa ode raksni       -- / 0
# 4    0.00 / 0               Vannisya Tri Hapsari       -- / 0
#
#    Nama [Feedback]  Kelas Kelas [Score]  Kelas [Feedback]  \
# 0              NaN  D4-KS        -- / 0               NaN
# 1              NaN  D3-ST        -- / 0               NaN
# 2              NaN  D4-KS        -- / 0               NaN
# 3              NaN  D4-KS        -- / 0               NaN
# 4              NaN  D4-KS        -- / 0               NaN
#
#    Bagaimana Tipe Belajarmu? Bagaimana Tipe Belajarmu? [Score]  \
# 0                          2                            -- / 0
# 1                          2                            -- / 0
# ...

# %%
del df['Total score']

# %%
df.head()
# Out:
#                                 Nama Nama [Score]  Nama [Feedback]  Kelas  \
# 0                           Saffanah       -- / 0              NaN  D4-KS
# 1  Islamiati Yulia Mustikasari Lessy       -- / 0              NaN  D3-ST
# 2                         Muhammad H       -- / 0              NaN  D4-KS
# 3                      Wa ode raksni       -- / 0              NaN  D4-KS
# 4               Vannisya Tri Hapsari       -- / 0              NaN  D4-KS
#
#   Kelas [Score]  Kelas [Feedback]  Bagaimana Tipe Belajarmu?  \
# 0        -- / 0               NaN                          2
# 1        -- / 0               NaN                          2
# 2        -- / 0               NaN                          3
# 3        -- / 0               NaN                          1
# 4        -- / 0               NaN                          2
#
#   Bagaimana Tipe Belajarmu? [Score]  Bagaimana Tipe Belajarmu? [Feedback]  \
# 0                            -- / 0                                   NaN
# ...

# %%
del df['Nama [Score]']

# %%
df.head()
# Out:
#                                 Nama  Nama [Feedback]  Kelas Kelas [Score]  \
# 0                           Saffanah              NaN  D4-KS        -- / 0
# 1  Islamiati Yulia Mustikasari Lessy              NaN  D3-ST        -- / 0
# 2                         Muhammad H              NaN  D4-KS        -- / 0
# 3                      Wa ode raksni              NaN  D4-KS        -- / 0
# 4               Vannisya Tri Hapsari              NaN  D4-KS        -- / 0
#
#    Kelas [Feedback]  Bagaimana Tipe Belajarmu?  \
# 0               NaN                          2
# 1               NaN                          2
# 2               NaN                          3
# 3               NaN                          1
# 4               NaN                          2
#
#   Bagaimana Tipe Belajarmu? [Score]  Bagaimana Tipe Belajarmu? [Feedback]  \
# 0                            -- / 0                                   NaN
# 1                            -- / 0                                   NaN
# ...

# %%
del df['Nama [Feedback]']

# %%
df.head()
# Out:
#                                 Nama  Kelas Kelas [Score]  Kelas [Feedback]  \
# 0                           Saffanah  D4-KS        -- / 0               NaN
# 1  Islamiati Yulia Mustikasari Lessy  D3-ST        -- / 0               NaN
# 2                         Muhammad H  D4-KS        -- / 0               NaN
# 3                      Wa ode raksni  D4-KS        -- / 0               NaN
# 4               Vannisya Tri Hapsari  D4-KS        -- / 0               NaN
#
#    Bagaimana Tipe Belajarmu? Bagaimana Tipe Belajarmu? [Score]  \
# 0                          2                            -- / 0
# 1                          2                            -- / 0
# 2                          3                            -- / 0
# 3                          1                            -- / 0
# 4                          2                            -- / 0
#
#    Bagaimana Tipe Belajarmu? [Feedback]  Kapan kamu belajar?  \
# 0                                   NaN                    3
# ...

# %%
del df['Kelas [Score]']

# %%
df.head()
# Out:
#                                 Nama  Kelas  Kelas [Feedback]  \
# 0                           Saffanah  D4-KS               NaN
# 1  Islamiati Yulia Mustikasari Lessy  D3-ST               NaN
# 2                         Muhammad H  D4-KS               NaN
# 3                      Wa ode raksni  D4-KS               NaN
# 4               Vannisya Tri Hapsari  D4-KS               NaN
#
#    Bagaimana Tipe Belajarmu? Bagaimana Tipe Belajarmu? [Score]  \
# 0                          2                            -- / 0
# 1                          2                            -- / 0
# 2                          3                            -- / 0
# 3                          1                            -- / 0
# 4                          2                            -- / 0
#
#    Bagaimana Tipe Belajarmu? [Feedback]  Kapan kamu belajar?  \
# 0                                   NaN                    3
# 1                                   NaN                    3
# ...

# %%
del df['Kelas [Feedback]']

# %%
df.head()
# Out:
#                                 Nama  Kelas  Bagaimana Tipe Belajarmu?  \
# 0                           Saffanah  D4-KS                          2
# 1  Islamiati Yulia Mustikasari Lessy  D3-ST                          2
# 2                         Muhammad H  D4-KS                          3
# 3                      Wa ode raksni  D4-KS                          1
# 4               Vannisya Tri Hapsari  D4-KS                          2
#
#   Bagaimana Tipe Belajarmu? [Score]  Bagaimana Tipe Belajarmu? [Feedback]  \
# 0                            -- / 0                                   NaN
# 1                            -- / 0                                   NaN
# 2                            -- / 0                                   NaN
# 3                            -- / 0                                   NaN
# 4                            -- / 0                                   NaN
#
#    Kapan kamu belajar? Kapan kamu belajar? [Score]  \
# ...

# %%
del df['Bagaimana Tipe Belajarmu? [Score]']

# %%
df.head()
# Out:
#                                 Nama  Kelas  Bagaimana Tipe Belajarmu?  \
# 0                           Saffanah  D4-KS                          2
# 1  Islamiati Yulia Mustikasari Lessy  D3-ST                          2
# 2                         Muhammad H  D4-KS                          3
# 3                      Wa ode raksni  D4-KS                          1
# 4               Vannisya Tri Hapsari  D4-KS                          2
#
#    Bagaimana Tipe Belajarmu? [Feedback]  Kapan kamu belajar?  \
# 0                                   NaN                    3
# 1                                   NaN                    3
# 2                                   NaN                    2
# 3                                   NaN                    3
# 4                                   NaN                    3
#
#   Kapan kamu belajar? [Score]  Kapan kamu belajar? [Feedback]  \
# 0                      -- / 0                             NaN
# ...

# %%
del df['Bagaimana Tipe Belajarmu? [Feedback]']

# %%
df.head()
# Out:
#                                 Nama  Kelas  Bagaimana Tipe Belajarmu?  \
# 0                           Saffanah  D4-KS                          2
# 1  Islamiati Yulia Mustikasari Lessy  D3-ST                          2
# 2                         Muhammad H  D4-KS                          3
# 3                      Wa ode raksni  D4-KS                          1
# 4               Vannisya Tri Hapsari  D4-KS                          2
#
#    Kapan kamu belajar? Kapan kamu belajar? [Score]  \
# 0                    3                      -- / 0
# 1                    3                      -- / 0
# 2                    2                      -- / 0
# 3                    3                      -- / 0
# 4                    3                      -- / 0
#
#    Kapan kamu belajar? [Feedback]  Sepenting apa IPK untukmu?  \
# 0                             NaN                           2
# 1                             NaN                           1
# ...

# %%
del df['Kapan kamu belajar? [Feedback]']

# %%
df.head()
# Out:
#                                 Nama  Kelas  Bagaimana Tipe Belajarmu?  \
# 0                           Saffanah  D4-KS                          2
# 1  Islamiati Yulia Mustikasari Lessy  D3-ST                          2
# 2                         Muhammad H  D4-KS                          3
# 3                      Wa ode raksni  D4-KS                          1
# 4               Vannisya Tri Hapsari  D4-KS                          2
#
#    Kapan kamu belajar? Kapan kamu belajar? [Score]  \
# 0                    3                      -- / 0
# 1                    3                      -- / 0
# 2                    2                      -- / 0
# 3                    3                      -- / 0
# 4                    3                      -- / 0
#
#    Sepenting apa IPK untukmu? Sepenting apa IPK untukmu? [Score]  \
# 0                           2                             -- / 0
# 1                           1                             -- / 0
# ...

# %%
del df['Kapan kamu belajar? [Score]']

# %%
df.head()
# Out:
#                                 Nama  Kelas  Bagaimana Tipe Belajarmu?  \
# 0                           Saffanah  D4-KS                          2
# 1  Islamiati Yulia Mustikasari Lessy  D3-ST                          2
# 2                         Muhammad H  D4-KS                          3
# 3                      Wa ode raksni  D4-KS                          1
# 4               Vannisya Tri Hapsari  D4-KS                          2
#
#    Kapan kamu belajar?  Sepenting apa IPK untukmu?  \
# 0                    3                           2
# 1                    3                           1
# 2                    2                           3
# 3                    3                           3
# 4                    3                           2
#
#   Sepenting apa IPK untukmu? [Score]  Sepenting apa IPK untukmu? [Feedback]  \
# 0                             -- / 0                                    NaN
# ...

# %%
del df['Sepenting apa IPK untukmu? [Score]']

# %%
df.head()
# Out:
#                                 Nama  Kelas  Bagaimana Tipe Belajarmu?  \
# 0                           Saffanah  D4-KS                          2
# 1  Islamiati Yulia Mustikasari Lessy  D3-ST                          2
# 2                         Muhammad H  D4-KS                          3
# 3                      Wa ode raksni  D4-KS                          1
# 4               Vannisya Tri Hapsari  D4-KS                          2
#
#    Kapan kamu belajar?  Sepenting apa IPK untukmu?  \
# 0                    3                           2
# 1                    3                           1
# 2                    2                           3
# 3                    3                           3
# 4                    3                           2
#
#    Sepenting apa IPK untukmu? [Feedback]  Kamu dalam mengerjakan tugas?  \
# 0                                    NaN                              3
# 1                                    NaN                              1
# ...

# %%
del df['Sepenting apa IPK untukmu? [Feedback]']

# %%
df.head()
# Out:
#                                 Nama  Kelas  Bagaimana Tipe Belajarmu?  \
# 0                           Saffanah  D4-KS                          2
# 1  Islamiati Yulia Mustikasari Lessy  D3-ST                          2
# 2                         Muhammad H  D4-KS                          3
# 3                      Wa ode raksni  D4-KS                          1
# 4               Vannisya Tri Hapsari  D4-KS                          2
#
#    Kapan kamu belajar?  Sepenting apa IPK untukmu?  \
# 0                    3                           2
# 1                    3                           1
# 2                    2                           3
# 3                    3                           3
# 4                    3                           2
#
#    Kamu dalam mengerjakan tugas? Kamu dalam mengerjakan tugas? [Score]  \
# 0                              3                                -- / 0
# 1                              1                                -- / 0
# ...

# %%
del df['Kamu dalam mengerjakan tugas? [Score]']

# %%
df.head()
# Out:
#                                 Nama  Kelas  Bagaimana Tipe Belajarmu?  \
# 0                           Saffanah  D4-KS                          2
# 1  Islamiati Yulia Mustikasari Lessy  D3-ST                          2
# 2                         Muhammad H  D4-KS                          3
# 3                      Wa ode raksni  D4-KS                          1
# 4               Vannisya Tri Hapsari  D4-KS                          2
#
#    Kapan kamu belajar?  Sepenting apa IPK untukmu?  \
# 0                    3                           2
# 1                    3                           1
# 2                    2                           3
# 3                    3                           3
# 4                    3                           2
#
#    Kamu dalam mengerjakan tugas?  Kamu dalam mengerjakan tugas? [Feedback]  \
# 0                              3                                       NaN
# 1                              1                                       NaN
# ...

# %%
del df['Kamu dalam mengerjakan tugas? [Feedback]']

# %%
df.head()
# Out:
#                                 Nama  Kelas  Bagaimana Tipe Belajarmu?  \
# 0                           Saffanah  D4-KS                          2
# 1  Islamiati Yulia Mustikasari Lessy  D3-ST                          2
# 2                         Muhammad H  D4-KS                          3
# 3                      Wa ode raksni  D4-KS                          1
# 4               Vannisya Tri Hapsari  D4-KS                          2
#
#    Kapan kamu belajar?  Sepenting apa IPK untukmu?  \
# 0                    3                           2
# 1                    3                           1
# 2                    2                           3
# 3                    3                           3
# 4                    3                           2
#
#    Kamu dalam mengerjakan tugas?  Tingkat paham materi kuliahmu?  \
# 0                              3                               2
# 1                              1                               2
# ...

# %%
del df['Tingkat paham materi kuliahmu? [Score]']

# %%
df.head()
# Out:
#                                 Nama  Kelas  Bagaimana Tipe Belajarmu?  \
# 0                           Saffanah  D4-KS                          2
# 1  Islamiati Yulia Mustikasari Lessy  D3-ST                          2
# 2                         Muhammad H  D4-KS                          3
# 3                      Wa ode raksni  D4-KS                          1
# 4               Vannisya Tri Hapsari  D4-KS                          2
#
#    Kapan kamu belajar?  Sepenting apa IPK untukmu?  \
# 0                    3                           2
# 1                    3                           1
# 2                    2                           3
# 3                    3                           3
# 4                    3                           2
#
#    Kamu dalam mengerjakan tugas?  Tingkat paham materi kuliahmu?  \
# 0                              3                               2
# 1                              1                               2
# ...

# %%
del df['Tingkat paham materi kuliahmu? [Feedback]']

# %%
df.head()
# Out:
#                                 Nama  Kelas  Bagaimana Tipe Belajarmu?  \
# 0                           Saffanah  D4-KS                          2
# 1  Islamiati Yulia Mustikasari Lessy  D3-ST                          2
# 2                         Muhammad H  D4-KS                          3
# 3                      Wa ode raksni  D4-KS                          1
# 4               Vannisya Tri Hapsari  D4-KS                          2
#
#    Kapan kamu belajar?  Sepenting apa IPK untukmu?  \
# 0                    3                           2
# 1                    3                           1
# 2                    2                           3
# 3                    3                           3
# 4                    3                           2
#
#    Kamu dalam mengerjakan tugas?  Tingkat paham materi kuliahmu?
# 0                              3                               2
# 1                              1                               2
# ...

# %%
df.columns= ['Nama', 'Kelas', 'Tipe', 'Waktu' , 'IPK', 'Tugas', 'Materi']

# %%
df.head()
# Out:
#                                 Nama  Kelas  Tipe  Waktu  IPK  Tugas  Materi
# 0                           Saffanah  D4-KS     2      3    2      3       2
# 1  Islamiati Yulia Mustikasari Lessy  D3-ST     2      3    1      1       2
# 2                         Muhammad H  D4-KS     3      2    3      2       2
# 3                      Wa ode raksni  D4-KS     1      3    3      1       2
# 4               Vannisya Tri Hapsari  D4-KS     2      3    2      2       2

# %%
df['Kelas'] = df['Kelas'].apply(lambda x: 0 if x == 'D4-KS' else 1  )

# %%
ks_df = df[df['Kelas'] == 0]
st_df = df[df['Kelas'] == 1]

# %%
ks_X = ks_df.drop(['Nama', 'Kelas'], axis = 1)
st_X = st_df.drop(['Nama', 'Kelas'], axis = 1)

# %% [markdown]
# # MODEL DEVELOPMENT
#
# Disini saya membuat pengelompokan beberapa orang berdasarkan kesamaan mereka melalui pendekatan kebiasaan dengan tujuan mereka dapat menemukan orang yang sefrekuensi dengan diri mereka masing-masing agar dapat berteman dan bereklompok.

# %%
ks_nbrs = NearestNeighbors(n_neighbors=5).fit(ks_X)
st_nbrs = NearestNeighbors(n_neighbors=5).fit(st_X)

# %%
X = df.drop(['Nama','Kelas'], axis = 1 )

# %%
test = X[df['Nama'] == 'Wa ode raksni'].values

# %%
_, idx= ks_nbrs.kneighbors(test)

# %%
idx
# Out:
# array([[ 2,  5, 19,  9, 16]], dtype=int64)

# %%
ks_df.iloc[idx[0]]['Nama']
# Out:
# 3                  Wa ode raksni
# 6                          Alwan
# 45              Nur Ainun Daulay
# 23    Nicholas Hanerson Manurung
# 41              Zuhdi Ali Hisyam
# Name: Nama, dtype: object

# %% [markdown]
# # STATISTIK DAN ANALISIS

# %% [markdown]
# ###### STATISTIK DASAR DATA "How To Make Sirkel Di STIS"

# %%
 df.describe()
# Out:
#             Kelas        Tipe       Waktu        IPK       Tugas      Materi
# count  100.000000  100.000000  100.000000  100.00000  100.000000  100.000000
# mean     0.700000    1.950000    2.520000    2.44000    2.040000    1.950000
# std      0.460566    0.592461    0.703239    0.51874    0.709531    0.411329
# min      0.000000    1.000000    1.000000    1.00000    1.000000    1.000000
# 25%      0.000000    2.000000    2.000000    2.00000    2.000000    2.000000
# 50%      1.000000    2.000000    3.000000    2.00000    2.000000    2.000000
# 75%      1.000000    2.000000    3.000000    3.00000    3.000000    2.000000
# max      1.000000    3.000000    3.000000    3.00000    3.000000    3.000000

# %%
import matplotlib.pyplot as plt


x_ax = ["Tipe", "Waktu", "IPK", "Tugas", "Materi"]
y_ax = [df.Tipe.mean(), df.Waktu.mean(), df.IPK.mean(), df.Tugas.mean(), df.Materi.mean()]
y_ks = [ks_df.Tipe.mean(), ks_df.Waktu.mean(), ks_df.IPK.mean(), ks_df.Tugas.mean(), ks_df.Materi.mean()]
y_st = [st_df.Tipe.mean(), st_df.Waktu.mean(), st_df.IPK.mean(), st_df.Tugas.mean(), st_df.Materi.mean()]


fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.set_title("Rata-rata preferensi KS dan ST")

plt.plot(x_ax, y_ax, label="Umum")
plt.plot(x_ax, y_ks, label="KS")
plt.plot(x_ax, y_st, label="ST")

ax.legend()

# %% [markdown]
# ###### Analisis dan Insight "How To Make Sirkel Di STIS"
#
#     Dari survey yang saya lakukan "How To Make Sirkel Di STIS" yang memiliki 100 responden, saya melakukan survey dengan
#     tujuan untuk membuat Mahasiswa di STIS dapat menemukan teman belajar dan kemudian berkelompok.
#     Dari survey tersebut saya mendapatkan :
#  1. Hal terpenting bagi teman-teman adalah waktu belajar yang sama.
#  2. Sedangkan preferensi yang dianggap tidak penting adalah tipe belajar.
#  3. Responden Terbanyak adalah dari prodi ST.
#  4. Dari test model development yang saya lakukan, Wa Ode Raksni memiliki korelasi positif dengan  Alwan, Nur Ainun Daulay,Nicholas Hanerson Manurung,dan Zuhdi Ali Hisyam.
#  5. Kemungkinan besar, apabila saya melakukan pengelompokan lagi dengan mengambil model dari kelompok yang sama dengan anggota dari kelompok Wa Ode Raksni maka juga akan didapatkan hasil kelompok yang sama.
