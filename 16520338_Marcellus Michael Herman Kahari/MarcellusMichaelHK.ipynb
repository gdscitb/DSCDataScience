# %%
#### Nama : Marcellus Michael Herman Kahari
#### NIM : 16520338
#### Institut Teknologi Bandung
#### Tanggal : 15 November 2020
#### Dataset : TakeMeOut.scv

# %%
import pandas as pd
from sklearn.neighbors import NearestNeighbors

# %%
df = pd.read_csv('takemeout.csv')

# %%
df.head()
# Out:
#                      Timestamp Siapa nama kamu? Cewek atau cowok nih?  \
# 0  2020/10/31 3:39:25 PM GMT+7  A**************                 Cowok
# 1  2020/10/31 3:39:36 PM GMT+7            L****                 Cewek
# 2  2020/10/31 3:39:38 PM GMT+7     Y***********                 Cowok
# 3  2020/10/31 3:39:42 PM GMT+7             a***                 Cowok
# 4  2020/10/31 3:39:43 PM GMT+7            B****                 Cowok
#
#    Seberapa penting quality time bareng calon pacar untuk kamu?  \
# 0                                                  5
# 1                                                  5
# 2                                                  4
# 3                                                  5
# 4                                                  5
#
#    Seberapa penting physical touch sama calon pacar untuk kamu?  \
# 0                                                  5
# 1                                                  5
# ...

# %%
# Data Preprocessing

# %%
df = df.iloc[:,1:]

# %%
df.head()
# Out:
#   Siapa nama kamu? Cewek atau cowok nih?  \
# 0  A**************                 Cowok
# 1            L****                 Cewek
# 2     Y***********                 Cowok
# 3             a***                 Cowok
# 4            B****                 Cowok
#
#    Seberapa penting quality time bareng calon pacar untuk kamu?  \
# 0                                                  5
# 1                                                  5
# 2                                                  4
# 3                                                  5
# 4                                                  5
#
#    Seberapa penting physical touch sama calon pacar untuk kamu?  \
# 0                                                  5
# 1                                                  5
# 2                                                  3
# 3                                                  5
# 4                                                  5
#
# ...

# %%
df.columns = ['nama', 'gender', 'qt', 'touch', 'word', 'kado', 'bantuan']

# %%
df.head()
# Out:
#               nama gender  qt  touch  word  kado  bantuan
# 0  A**************  Cowok   5      5     4     1        3
# 1            L****  Cewek   5      5     3     2        2
# 2     Y***********  Cowok   4      3     4     4        4
# 3             a***  Cowok   5      5     5     2        3
# 4            B****  Cowok   5      5     5     2        4

# %%
df['gender'] = df['gender'].apply(lambda x: 0 if x == 'Cowok' else 1)

# %%
df.head()
# Out:
#               nama  gender  qt  touch  word  kado  bantuan
# 0  A**************       0   5      5     4     1        3
# 1            L****       1   5      5     3     2        2
# 2     Y***********       0   4      3     4     4        4
# 3             a***       0   5      5     5     2        3
# 4            B****       0   5      5     5     2        4

# %%
m_df = df[df['gender']==0]
f_df = df[df['gender']==1]

# %%
df.head()
# Out:
#               nama  gender  qt  touch  word  kado  bantuan
# 0  A**************       0   5      5     4     1        3
# 1            L****       1   5      5     3     2        2
# 2     Y***********       0   4      3     4     4        4
# 3             a***       0   5      5     5     2        3
# 4            B****       0   5      5     5     2        4

# %%
m_X = m_df.drop(['nama', 'gender'],axis=1)
f_X = f_df.drop(['nama', 'gender'],axis=1)

# %%
# Model Development

# %%
m_nbrs = NearestNeighbors(n_neighbors=5).fit(m_X)
f_nbrs = NearestNeighbors(n_neighbors=5).fit(f_X)

# %%
X = df.drop(['nama','gender'],axis=1)

# %%
test = X[df['nama'] == input()].values

# %%
_, idx = f_nbrs.kneighbors(test)

# %%
idx

# %%
f_df.iloc[id[0]]['name']

# %%
# Data Insight

# %%
print(m_df['qt'].mean())
print(m_df['qt'].min())
print(m_df['qt'].max())
# Out:
# 4.185185185185185
# 1
# 5

# %%
print(f_df['qt'].mean())
print(f_df['qt'].min())
print(f_df['qt'].max())
# Out:
# 3.75
# 1
# 5

# %%
#### Jadi dalam hal quality time, rata-rata para pria lebih tinggi dibandingkan rata-rata para wanita
#### dalam hal pentingnya quality time dalam suatu hubungan.

# %%
print(m_df['bantuan'].mean())
print(m_df['bantuan'].min())
print(m_df['bantuan'].max())
# Out:
# 3.765432098765432
# 1
# 5

# %%
print(f_df['bantuan'].mean())
print(f_df['bantuan'].min())
print(f_df['bantuan'].max())
# Out:
# 3.7
# 1
# 5

# %%
#### Jadi dalam hal memberikan bantuan, rata-rata pria dan wanita yang merasakan pentingnya bantuan dari pasangan adalah sama.
